# %%
#Import packages
import nltk, re, string, random, tqdm
import pandas as pd
import tqdm 
import matplotlib.pyplot as plt 
from matplotlib import ticker

from nltk import classify, NaiveBayesClassifier, FreqDist
from nltk.tokenize import word_tokenize
from nltk.corpus import twitter_samples
from nltk.corpus import stopwords
from nltk.tag import pos_tag
from nltk.stem.wordnet import WordNetLemmatizer

nltk.download('punkt')
nltk.download('twitter_samples')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Anders\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     C:\Users\Anders\AppData\Roaming\nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Anders\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Anders\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Anders\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Raw training data

positive_tweets = twitter_samples.strings('positive_tweets.json')
negative_tweets = twitter_samples.strings('negative_tweets.json')
text = twitter_samples.strings('tweets.20150430-223406.json')

# %%
#lematization funtion, normalises words to canonical form
def lemmatize_sentence(tokens):
    lemmatizer = WordNetLemmatizer()
    lemmatized_sentence = []
    for word, tag in pos_tag(tokens):
        if tag.startswith('NN'):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'
        lemmatized_sentence.append(lemmatizer.lemmatize(word, pos))
    return lemmatized_sentence

# %%
#Function to remove noise (the, it, @ for twitter handles and others)
def remove_noise(tweet_tokens, stop_words = ()):

    cleaned_tokens = []

    for token, tag in pos_tag(tweet_tokens):
        token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
                       '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
        token = re.sub("(@[A-Za-z0-9_]+)","", token)

        if tag.startswith("NN"):
            pos = 'n'
        elif tag.startswith('VB'):
            pos = 'v'
        else:
            pos = 'a'

        lemmatizer = WordNetLemmatizer()
        token = lemmatizer.lemmatize(token, pos)

        if len(token) > 0 and token not in string.punctuation and token.lower() not in stop_words:
            cleaned_tokens.append(token.lower())
    return cleaned_tokens

# %%
#Make clean sample out of cleaned data
stop_words = stopwords.words('english')

positive_tweet_tokens = twitter_samples.tokenized('positive_tweets.json')
negative_tweet_tokens = twitter_samples.tokenized('negative_tweets.json')

positive_cleaned_tokens_list = []
negative_cleaned_tokens_list = []

for tokens in positive_tweet_tokens:
    positive_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

for tokens in negative_tweet_tokens:
    negative_cleaned_tokens_list.append(remove_noise(tokens, stop_words))

# %%
#Word density function
def get_all_words(cleaned_tokens_list):
    for tokens in cleaned_tokens_list:
        for token in tokens:
            yield token

all_pos_words = get_all_words(positive_cleaned_tokens_list)

freq_dist_pos = FreqDist(all_pos_words)
#print(freq_dist_pos.most_common(10))

# %%
#Frequency distribution
freq_dist_pos = FreqDist(all_pos_words)
#print(freq_dist_pos.most_common(10))

# %%
#Function to fetch cleaned tokens for modelling
def get_tweets_for_model(cleaned_tokens_list):
    for tweet_tokens in cleaned_tokens_list:
        yield dict([token, True] for token in tweet_tokens)

positive_tokens_for_model = get_tweets_for_model(positive_cleaned_tokens_list)
negative_tokens_for_model = get_tweets_for_model(negative_cleaned_tokens_list)

# %%
print(len(positive_cleaned_tokens_list))
print(len(negative_cleaned_tokens_list))
# Out:
# 5000
# 5000

# %%
#Split dataset
positive_dataset = [(tweet_dict, "Positive")
                     for tweet_dict in positive_tokens_for_model]

negative_dataset = [(tweet_dict, "Negative")
                     for tweet_dict in negative_tokens_for_model]

dataset = positive_dataset + negative_dataset

random.shuffle(dataset)

train_data = dataset[:7000]
test_data = dataset[7000:]

# %%
#classifier
classifier = NaiveBayesClassifier.train(train_data)

print("Accuracy is:", classify.accuracy(classifier, test_data))

print(classifier.show_most_informative_features(10))
# Out:
# Accuracy is: 0.995
# Most Informative Features
#                       :) = True           Positi : Negati =    990.3 : 1.0
#                  welcome = True           Positi : Negati =     21.3 : 1.0
#                 follower = True           Positi : Negati =     20.9 : 1.0
#                   arrive = True           Positi : Negati =     18.5 : 1.0
#                      bam = True           Positi : Negati =     18.2 : 1.0
#                      sad = True           Negati : Positi =     18.2 : 1.0
#                   friday = True           Positi : Negati =     15.8 : 1.0
#                      via = True           Positi : Negati =     15.8 : 1.0
#                    didnt = True           Negati : Positi =     13.7 : 1.0
#                community = True           Positi : Negati =     13.6 : 1.0
# None

# %%
#Custom tweet tester, model seems to not understand sarcasm
custom_tweet = 'doge is the shitty coin'

custom_tokens = remove_noise(word_tokenize(custom_tweet))

print(classifier.classify(dict([token, True] for token in custom_tokens)))
# Out:
# Positive

# %% [markdown]
# ## Defining function to do sentiment analysis

# %%
def sentiment_analysis(DataFrame, column_name):
    """
    Takes in a DataFrame, and a string specifying the name of the column where the tweets are located
    Returns the DataFrame with a sentiment analysis column appended 
    """
    
    #Creating temp_list of all text bits in DataFrame
    temp_list = DataFrame[column_name].tolist()
    
    # For loop that finds sentiment of each element in temp list as -1 (negative) or 1 (positive)

    output_list = []

    for i in tqdm.tqdm(temp_list):
        custom_text = str(i)
        custom_tokens = remove_noise(word_tokenize(custom_text))
        if classifier.classify(dict([token, True] for token in custom_tokens)) == 'Negative':
            output_list.append(-1)
        else:
            output_list.append(1)
    DataFrame['sentiment'] = pd.DataFrame(output_list)
    
    return DataFrame

# %% [markdown]
# # 7-day Twitter API Dataset - Sentiment analysis

# %% [markdown]
# ### Load in dataset

# %%
twitter_API_df = pd.read_csv('twitter_API_data_cleaned.csv', encoding='utf-8')

# %% [markdown]
# ### OBS: Takes around 10 mins to run

# %%
### OLD CODE ###

#Creating temp_list of all text bits in DataFrame

#temp_list = twitter_API_df['text'].tolist()

# For loop that finds sentiment of each element in temp list as -1 (negative) or 1 (positive)

#output_list = []

#for i in tqdm.tqdm(temp_list):
#    custom_text = str(i)
#    custom_tokens = remove_noise(word_tokenize(custom_text))
#    if classifier.classify(dict([token, True] for token in custom_tokens)) == 'Negative':
#        output_list.append(-1)
#    else:
#        output_list.append(1)
#output_df = pd.DataFrame(output_list)
#
#output_df.head(5)

# %%
twitter_API_df = sentiment_analysis(twitter_API_df, 'text')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 145933/145933 [11:58<00:00, 203.21it/s]

# %%
twitter_API_df.head(2)
# Out:
#                                                 text            author_id  \
# 0  @alqsyy @Mutantduckclub8 RYOGE- The shiba kill...  1557092549638111233
# 1  @Amrit45970471 @palletjacker69 Join doge mutan...  1551828952011997184
#
#          date            date_hour  retweet_count  reply_count  like_count  \
# 0  2022-08-15  2022-08-15 14:00:00              0            0           0
# 1  2022-08-15  2022-08-15 14:00:00              0            0           0
#
#    quote_count  sentiment
# 0            0         -1
# 1            0          1

# %%
### OLD CODE ###

# Adding the sentiment as a column to the OG DataFrame
#twitter_API_df['sentiment'] = output_df

#twitter_API_df.head(2)

# %% [markdown]
# ### Saving as CSV file for later use

# %%
twitter_API_df.to_csv('twitter_API_data_sentiment_NLKT.csv', index=False)

# %% [markdown]
# ## Grouping

# %%
### Number of tweets mentioning 'doge' in each sentiment category
tweets_by_sentiment = twitter_API_df['text'].groupby(twitter_API_df['sentiment']).count()

### Sum and mean of numerical sentiment value per day (ie. "Sentiment per day/hour")
sum_sentiment_per_day = twitter_API_df['sentiment'].groupby(twitter_API_df['date']).sum()
mean_sentiment_per_day = twitter_API_df['sentiment'].groupby(twitter_API_df['date']).mean()

sum_sentiment_per_hour = twitter_API_df['sentiment'].groupby(twitter_API_df['date_hour']).sum()
mean_sentiment_per_hour = twitter_API_df['sentiment'].groupby(twitter_API_df['date_hour']).mean()

#Dataframe with sum and mean per hour
sentiment_per_hour = pd.DataFrame({'Sum': sum_sentiment_per_hour, 'Mean': mean_sentiment_per_hour}).reset_index()

# %% [markdown]
# ### Saving sentiment_per_hour as CSV for later use

# %%
sentiment_per_hour.to_csv('twitter_API_data_sentiment_NLKT_per_hour.csv', index=False)

# %% [markdown]
# ### General distribution of sentiment

# %%
plt.bar(['negative', 'positive'], tweets_by_sentiment, color =['maroon','limegreen'])
plt.title('Number of tweets by sentiment \n rating using NLKT')

plt.show()

# %% [markdown]
# ### Basic plotting for visual analysis

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2,ncols=2, figsize=(12,8))

ax1[0].plot(mean_sentiment_per_day)
ax1[0].set_title('Mean of sentiment using NLKT per day')
ax1[0].tick_params(axis='x',rotation=90)

ax1[1].plot(sum_sentiment_per_day)
ax1[1].set_title('Sum of sentiment using NLKT per day')
ax1[1].tick_params(axis='x',rotation=90)


ax2[0].plot(mean_sentiment_per_hour)
ax2[0].set_title('Mean of sentiment using NLKT per hour')
ax2[0].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax2[0].tick_params(axis='x',rotation=90)

ax2[1].plot(sum_sentiment_per_hour)
ax2[1].set_title('Sum of sentiment using NLKT per hour')
ax2[1].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax2[1].tick_params(axis='x',rotation=90)


fig.tight_layout()
plt.show()

# %% [markdown]
# # 73-day Twitter Dataset

# %% [markdown]
# ### Load in dataset

# %%
twitter_73_days = pd.read_csv('twitter_73_days_cleaned.csv', encoding='utf-8')

# %%
twitter_73_days.head()
# Out:
#               User               Date Created  Number of Likes  \
# 0    DogecoinCuban  2021-12-31 23:59:58+00:00                1
# 1          RNY1117  2021-12-31 23:59:47+00:00                2
# 2          bojodus  2021-12-31 23:59:37+00:00                0
# 3    CryptoCapflow  2021-12-31 23:59:09+00:00                0
# 4  CarlosS74671189  2021-12-31 23:59:04+00:00                1
#
#                                                Tweet        Date  \
# 0  @Rodolfo07351753 @sodogetip tip @Rodolfo073517...  2021-12-31
# 1                                HAPPY NEW DOGE YEAR  2021-12-31
# 2  Prayers Up for XRP, DOGE , SHIB \nx1000 to the...  2021-12-31
# 3  [Spot] By 2021-12-31 14:00 GMT, DOGE total tra...  2021-12-31
# 4  @Darlene_Pizarro How much Doge would you like ...  2021-12-31
#
#              Date_Hour
# 0  2021-12-31 23:00:00
# 1  2021-12-31 23:00:00
# 2  2021-12-31 23:00:00
# 3  2021-12-31 23:00:00
# 4  2021-12-31 23:00:00

# %% [markdown]
# ### Running analysis
#
# ### OBS: Takes around 1 hr and 16 mins to run

# %%
twitter_73_days = sentiment_analysis(twitter_73_days, 'Tweet')
# Out:
#   1%|█                                                                      | 17895/1194435 [00:54<1:00:16, 325.37it/s]
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\anaconda3\lib\genericpath.py in isfile(path)
#      29     try:
# ---> 30         st = os.stat(path)
#      31     except (OSError, ValueError):
#
# FileNotFoundError: [WinError 2] Den angivne fil blev ikke fundet: 'C:\\Users\\Anders/nltk_data'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-83-d03afa6470a1> in <module>
# ----> 1 twitter_73_days = sentiment_analysis(twitter_73_days, 'Tweet')
#
# <ipython-input-4-fbdd3dfcafb1> in sentiment_analysis(DataFrame, column_name)
#      14     for i in tqdm.tqdm(temp_list):
#      15         custom_text = str(i)
# ---> 16         custom_tokens = remove_noise(word_tokenize(custom_text))
#      17         if classifier.classify(dict([token, True] for token in custom_tokens)) == 'Negative':
#      18             output_list.append(-1)
#
# <ipython-input-9-4c7979d85713> in remove_noise(tweet_tokens, stop_words)
#       4     cleaned_tokens = []
#       5
# ----> 6     for token, tag in pos_tag(tweet_tokens):
#       7         token = re.sub('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+#]|[!*\(\),]|'\
#       8                        '(?:%[0-9a-fA-F][0-9a-fA-F]))+','', token)
#
# ~\anaconda3\lib\site-packages\nltk\tag\__init__.py in pos_tag(tokens, tagset, lang)
#     158     :rtype: list(tuple(str, str))
#     159     """
# --> 160     tagger = _get_tagger(lang)
#     161     return _pos_tag(tokens, tagset, tagger, lang)
#     162
#
# ~\anaconda3\lib\site-packages\nltk\tag\__init__.py in _get_tagger(lang)
#     104         tagger.load(ap_russian_model_loc)
#     105     else:
# --> 106         tagger = PerceptronTagger()
#     107     return tagger
#     108
#
# ~\anaconda3\lib\site-packages\nltk\tag\perceptron.py in __init__(self, load)
#     166         if load:
#     167             AP_MODEL_LOC = "file:" + str(
# --> 168                 find("taggers/averaged_perceptron_tagger/" + PICKLE)
#     169             )
#     170             self.load(AP_MODEL_LOC)
#
# ~\anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     522     for path_ in paths:
#     523         # Is the path item a zipfile?
# --> 524         if path_ and (os.path.isfile(path_) and path_.endswith(".zip")):
#     525             try:
#     526                 return ZipFilePathPointer(path_, resource_name)
#
# ~\anaconda3\lib\genericpath.py in isfile(path)
#      28     """Test whether a path is a regular file"""
#      29     try:
# ---> 30         st = os.stat(path)
#      31     except (OSError, ValueError):
#      32         return False
#
# KeyboardInterrupt:

# %%
twitter_73_days.head(2)
# Out:
#             User               Date Created  Number of Likes  \
# 0  DogecoinCuban  2021-12-31 23:59:58+00:00                1
# 1        RNY1117  2021-12-31 23:59:47+00:00                2
#
#                                                Tweet        Date  \
# 0  @Rodolfo07351753 @sodogetip tip @Rodolfo073517...  2021-12-31
# 1                                HAPPY NEW DOGE YEAR  2021-12-31
#
#              Date_Hour  sentiment
# 0  2021-12-31 23:00:00          1
# 1  2021-12-31 23:00:00          1

# %% [markdown]
# ### Saving as a CSV file for later use

# %%
twitter_73_days.to_csv('twitter_73_days_sentiment_NLKT.csv', index=False)

# %% [markdown]
# ## Grouping

# %%
twitter_73_days= pd.read_csv('twitter_73_days_sentiment_NLKT.csv')

# %%
### Number of tweets mentioning 'doge' in each sentiment category
tweets_by_sentiment_73 = twitter_73_days['Tweet'].groupby(twitter_73_days['sentiment']).count()

### Sum and mean of numerical sentiment value per day (ie. "Sentiment per day/hour")
sum_sentiment_per_day_73 = twitter_73_days['sentiment'].groupby(twitter_73_days['Date']).sum()
mean_sentiment_per_day_73 = twitter_73_days['sentiment'].groupby(twitter_73_days['Date']).mean()

sum_sentiment_per_hour_73 = twitter_73_days['sentiment'].groupby(twitter_73_days['Date_Hour']).sum()
mean_sentiment_per_hour_73 = twitter_73_days['sentiment'].groupby(twitter_73_days['Date_Hour']).mean()
vol_sentiment_per_hour_73 = twitter_73_days['sentiment'].groupby(twitter_73_days['Date_Hour']).count()
#Dataframe with sum and mean per hour
sentiment_per_hour_73 = pd.DataFrame({'Sum': sum_sentiment_per_hour_73, 'Mean': mean_sentiment_per_hour_73, 'Vol': vol_sentiment_per_hour_73}).reset_index()

# %% [markdown]
# ### Saving as CSV for machine learning use

# %%
sentiment_per_hour_73.to_csv('twitter_73_days_sentiment_NLKT_per_hour.csv', index=False)

# %% [markdown]
# ## Basic plotting

# %% [markdown]
# ### General distribution of sentiment

# %%
plt.bar(['negative', 'positive'], tweets_by_sentiment_73, color =['maroon','limegreen'])
plt.title('Number of tweets by sentiment rating using NLKT \n (73-days data set)')

plt.show()

# %% [markdown]
# ### Basic plotting for visual analysis

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2,ncols=2, figsize=(12,8))

ax1[0].plot(mean_sentiment_per_day_73)
ax1[0].set_title('Mean of sentiment using NLKT per day \n (73-days data set)')
ax1[0].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax1[0].tick_params(axis='x',rotation=90)

ax1[1].plot(sum_sentiment_per_day_73)
ax1[1].set_title('Sum of sentiment using NLKT per day \n (73-days data set)')
ax1[1].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax1[1].tick_params(axis='x',rotation=90)


ax2[0].plot(mean_sentiment_per_hour_73)
ax2[0].set_title('Mean of sentiment using NLKT per hour \n (73-days data set)')
ax2[0].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax2[0].tick_params(axis='x',rotation=90)

ax2[1].plot(sum_sentiment_per_hour_73)
ax2[1].set_title('Sum of sentiment using NLKT per hour \n (73-days data set)')
ax2[1].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax2[1].tick_params(axis='x',rotation=90)


fig.tight_layout()
plt.show()

# %% [markdown]
# # 1-year dataset

# %% [markdown]
# ### Load in CSV file

# %%
twitter_1yr = pd.read_csv('twitter_1yr_roberta.csv', encoding='utf-8')

# renaming Roberta sentiment column and changing to intergers
twitter_1yr.rename(columns = {'sentiment':'roberta sentiment'}, inplace = True)
twitter_1yr['roberta sentiment'] = twitter_1yr['roberta sentiment'].astype(int)

# %% [markdown]
# ### Run analysis function

# %%
twitter_1yr = sentiment_analysis(twitter_1yr, 'Tweet')
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████| 154547/154547 [06:45<00:00, 381.32it/s]

# %%
#Add date and date_hour columns as datetime objects:
twitter_1yr['Date_Hour'] = pd.to_datetime([str[:-11]+'00 00' for str in twitter_1yr['Date']], format='%Y %m %d %H %M %S')
twitter_1yr['Date'] = twitter_1yr['Date_Hour'].dt.date
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-72-72cdd0f928a7> in <module>
#       1 #Add date and date_hour columns as datetime objects:
# ----> 2 twitter_1yr['Date_Hour'] = pd.to_datetime([str[:-11]+'00 00' for str in twitter_1yr['Date']], format='%Y %m %d %H %M %S')
#       3 twitter_1yr['Date'] = twitter_1yr['Date_Hour'].dt.date
#       4
#       5 twitter_1yr
#
# <ipython-input-72-72cdd0f928a7> in <listcomp>(.0)
#       1 #Add date and date_hour columns as datetime objects:
# ----> 2 twitter_1yr['Date_Hour'] = pd.to_datetime([str[:-11]+'00 00' for str in twitter_1yr['Date']], format='%Y %m %d %H %M %S')
#       3 twitter_1yr['Date'] = twitter_1yr['Date_Hour'].dt.date
#       4
#       5 twitter_1yr
#
# TypeError: 'datetime.date' object is not subscriptable

# %%
twitter_1yr
# Out:
#               Date  Like Count  \
# 0       2021-04-01         172
# 1       2021-04-01          24
# 2       2021-04-01          28
# 3       2021-04-01          50
# 4       2021-04-01          67
# ...            ...         ...
# 154542  2021-09-12         133
# 154543  2021-09-03        1147
# 154544  2021-08-30         237
# 154545  2021-08-27         172
# 154546  2021-08-17        2896
#
#                                                     Tweet  roberta sentiment  \
# 0        And the winner of the poll is VECHAIN VeChain...                  1
# 1       i tried to find the top of this thread but it ...                  1
# 2       Alright everyone please list your name address...                  1
# 3           Breaking news sold all hbar and xrp for doge                   1
# 4                   Buy doge not hoge GiveThanksNotPranks                  1
# ...                                                   ...                ...
# 154542  Elon Musk put a literal Doge in his literal ho...                  1
# 154543             DOGE Deserves To Be Over 1 00 Already                   1
# 154544   30 in 240 Minutes RT Like amp Follow Join Tel...                  1
# 154545  Day 3 We are reaching 5000 holders listed in C...                  1
# 154546          Smash like if you think DOGE goes over 1                   1
#
#         sentiment           Date_Hour
# 0               1 2021-04-01 23:00:00
# 1              -1 2021-04-01 23:00:00
# 2               1 2021-04-01 23:00:00
# 3              -1 2021-04-01 23:00:00
# 4              -1 2021-04-01 23:00:00
# ...           ...                 ...
# 154542         -1 2021-09-12 22:00:00
# 154543          1 2021-09-03 15:00:00
# 154544          1 2021-08-30 10:00:00
# 154545          1 2021-08-27 03:00:00
# 154546          1 2021-08-17 16:00:00
#
# [154547 rows x 6 columns]

# %%
twitter_1yr.to_csv('twitter_1yr_sentiment_roberta_NLKT.csv', index=False)

# %% [markdown]
# ## Grouping
#
# ### For Roberta

# %%
### Number of tweets mentioning 'doge' in each sentiment category
tweets_by_sentiment_1_r = twitter_1yr['Tweet'].groupby(twitter_1yr['roberta sentiment']).count()

### Sum and mean of numerical sentiment value per day (ie. "Sentiment per day/hour")
sum_sentiment_per_day_1_r = twitter_1yr['roberta sentiment'].groupby(twitter_1yr['Date']).sum()
mean_sentiment_per_day_1_r = twitter_1yr['roberta sentiment'].groupby(twitter_1yr['Date']).mean()

sum_sentiment_per_hour_1_r = twitter_1yr['roberta sentiment'].groupby(twitter_1yr['Date_Hour']).sum()
mean_sentiment_per_hour_1_r = twitter_1yr['roberta sentiment'].groupby(twitter_1yr['Date_Hour']).mean()

#Dataframe with sum and mean per hour
sentiment_per_hour_1_r = pd.DataFrame({'Sum': sum_sentiment_per_hour_1_r, 'Mean': mean_sentiment_per_hour_1_r}).reset_index()

# %% [markdown]
# ### For NLTK

# %%
### Number of tweets mentioning 'doge' in each sentiment category
tweets_by_sentiment_1_NLTK = twitter_1yr['Tweet'].groupby(twitter_1yr['sentiment']).count()

### Sum and mean of numerical sentiment value per day (ie. "Sentiment per day/hour")
sum_sentiment_per_day_1_NLTK = twitter_1yr['sentiment'].groupby(twitter_1yr['Date']).sum()
mean_sentiment_per_day_1_NLTK = twitter_1yr['sentiment'].groupby(twitter_1yr['Date']).mean()

sum_sentiment_per_hour_1_NLTK = twitter_1yr['sentiment'].groupby(twitter_1yr['Date_Hour']).sum()
mean_sentiment_per_hour_1_NLTK = twitter_1yr['sentiment'].groupby(twitter_1yr['Date_Hour']).mean()

#Dataframe with sum and mean per hour
sentiment_per_hour_1_NLTK = pd.DataFrame({'Sum': sum_sentiment_per_hour_1_r, 'Mean': mean_sentiment_per_hour_1_r}).reset_index()

# %% [markdown]
# ### Saving the hourly grouped data as CSV files

# %%
sentiment_per_hour_1_r.to_csv('twitter_1yr_sentiment_roberta_per_hour.csv', index=False)

sentiment_per_hour_1_NLTK.to_csv('twitter_1yr_sentiment_NLTK_per_hour.csv', index=False)

# %% [markdown]
# ### Distribution of the two sentiment analyzers

# %%
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,4))

ax1.bar(['negative', 'neutral', 'positive'], tweets_by_sentiment_1_r, color =['maroon', 'royalblue', 'limegreen'])
ax1.set_title('Number of tweets by sentiment rating using Roberta \n (1-year data set)')

ax2.bar(['negative', 'positive'], tweets_by_sentiment_1_NLTK, color =['maroon', 'limegreen'])
ax2.set_title('Number of tweets by sentiment rating using NLKT \n (1-year data set)')

plt.show()

# %% [markdown]
# ## Basic plots - Roberta

# %%
fig, (ax1, ax2) = plt.subplots(nrows=2,ncols=2, figsize=(12,8))

ax1[0].plot(mean_sentiment_per_day_1_r)
ax1[0].set_title('Mean of sentiment using NLKT per day \n (1-year data set)')
ax1[0].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax1[0].tick_params(axis='x',rotation=90)

ax1[1].plot(sum_sentiment_per_day_1_r)
ax1[1].set_title('Sum of sentiment using NLKT per day \n (1-year data set)')
ax1[1].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax1[1].tick_params(axis='x',rotation=90)


ax2[0].plot(mean_sentiment_per_hour_1_r)
ax2[0].set_title('Mean of sentiment using NLKT per hour \n (1-year data set)')
ax2[0].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax2[0].tick_params(axis='x',rotation=90)

ax2[1].plot(sum_sentiment_per_hour_1_r)
ax2[1].set_title('Sum of sentiment using NLKT per hour \n (1-year data set)')
ax2[1].xaxis.set_major_locator(ticker.MaxNLocator(8))
ax2[1].tick_params(axis='x',rotation=90)


fig.tight_layout()
plt.show()
