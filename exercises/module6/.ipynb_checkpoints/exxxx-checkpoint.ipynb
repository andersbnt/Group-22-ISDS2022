# %% [markdown]
# # Exercises for Session 6: Web Scraping 1
#
# In session 5 you briefly touched upon extracting data from the internet. You worked with APIs which can be used to download data from a webpage in a structured way. Sometimes the webpage do not provide an API or the data you can download via the API is limited. In that case we will need to extract the data from the webpage ourselves.
#
# In the next three sessions you will learn how to extract data from a webpage when you cannot use an API. It involves mapping through the webpage (find the right URLs) and extracting the desired data from the webpage's HTML string (HTML: the underlying language behind a webpage).
#
# *(Note: I recommend to use Chrome as your browser during the next three sessions. Lectures and exercises are solely based on Chrome.)*

# %% [markdown]
# # Part 1: Scraping Jobnet.dk
#
# When we want to scrape a webpage, the first thing we do is to investigate the webpage. First, we need to get an overview of the URLs of all the webpages we want to scrape. Second, we download the HTML-string from the webpages. You can learn more about this in video 6.1:
#
# (I might talk a bit slow in some of the videos. Remember that you can turn up the speed on Youtube)

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('Xiu-acDIm28', width=640, height=360)

# %% [markdown]
# > **Ex. 6.1.1:** Go to  www.jobnet.dk and investigate the page. Locate the webpage that shows the job postings. Use the `request` module to extract the HTML-string of the webpage.
# >
# > Remember to add name and email to the header of your request, so the website managers can see that you are not a malicious actor.
#
# > *Note:* The HTML-string will not make a lot of sense right now, but try to take a look at it. In the next session we will learn how to extract data from the HTML-string.
#
# > *Note:* The website is in Danish, but it should be no problem for non-Danish speaking persons to solve the exercises.

# %%
import requests

response = requests.get('https://job.jobnet.dk/CV/FindWork?Offset=0&SortValue=BestMatch', 
                        headers={'name':'Anders Tørsløv','email':'fpb540@alumni.ku.dk'})

# %% [markdown]
# When you have completed exercise 6.1.1 you have scraped your first webpage! I.e., you have retrieved the HTML-string of the webpage you wanted to extract data from. In session 7 we will learn how to get the relevant data from the HTML-string. But first we want to learn about how to go through all the webpages we want to scrape and retrieve the HTML-strings behind: `mapping`

# %% [markdown]
# > **Ex. 6.1.2:** Start your `mapping`: We want to figure out what URLs we need to scrape to collect job posting data.
#
# > You will see that there are 20 job postings per page, and that you can click through the pages with job postings on the bottom of the page. Figure out what the structure of the URL is, so you can click through the job posting pages by changing the URL.
#
# > Describe the structure of the URL in plain words below. What is the relevant paging parameter (the parameter you need to change to go to the next webpage) and how does it behave when you change page?

# %% [markdown]
# ### Answer
# I find that the offset value is raised by 20 every time I go to the next page.

# %% [markdown]
# > **Ex. 6.1.3:** Make a list of the URLs of the first 5 webpages with job postings.
#
# > *Hint 1:* Design a `for loop` using the `range` function that changes the paging parameter in the URL.
# >
# > *Hint 2:* How do you change the paging parameter in the URL-string? Here string formatting is your friend! Read about it [here](https://realpython.com/python-string-formatting) (I recommend that you adopt the f-strings formatting which is a relatively new and nice feature in Python).

# %%
urls = []

for n in range(5):
    urls.append(f'https://job.jobnet.dk/CV/FindWork?Offset={n*20}&SortValue=BestMatch')
    
#or as list comprehension: urls = [f'https://job.jobnet.dk/CV/FindWork?Offset={n*20}&SortValue=BestMatch' for n in range(5)]

# %% [markdown]
# > **Ex. 6.1.4:** Now loop through the list and scrape the HTML-strings of all 5 webpages using the `request` module again and save the HTML-strings in a list.
#
# > - Use the `time.sleep()` function to limit the rate of your calls. This is important to avoid overloading the webpage's server. Worst case, you can be banned from the website.
#
# > - ***Extra:*** Monitor the time left to completing the loop by using `tqdm.tqdm()` function.

# %%
#Imports
import tqdm
import time

#Create empty list
scrape=[]

for url in tqdm.tqdm(urls):
    response = requests.get(url, headers={'name':'Anders Tørsløv','email':'fpb540@alumni.ku.dk'}) #requests and saves response
    html = response.text #saves html as text
    scrape.append(html) #adds html to the empty lyst
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:03<00:00,  1.59it/s]

# %% [markdown]
# #### In the video below (video 6.2) you will learn about logging and handling exceptions. Watch it before continuing with Ex.6.1.5

# %%
YouTubeVideo('d9fx8m7dQmI', width=640, height=360)

# %% [markdown]
# > **Ex. 6.1.5:** Repeat 6.1.4, but now log your activity as well.

# %%
#Import
import os

#Define log function as given in slides
def log(response,logfile,output_path=os.getcwd()):
    # Open or create the csv file
    if os.path.isfile(logfile): #If the log file exists, open it and allow for changes     
        log = open(logfile,'a')
    else: #If the log file does not exist, create it and make headers for the log variables
        log = open(logfile,'w')
        header = ['timestamp','status_code','length','output_file']
        log.write(';'.join(header) + "\n") #Make the headers and jump to new line
        
    # Gather log information
    status_code = response.status_code #Status code from the request result
    timestamp = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(time.time())) #Local time
    length = len(response.text) #Length of the HTML-string
    
    # Open the log file and append the gathered log information
    with open(logfile,'a') as log:
        log.write(f'{timestamp};{status_code};{length};{output_path}' + "\n") #Append the information and jump to new line

# %%
#Create empty list
scrape=[]
logfile= 'log.csv'

for url in tqdm.tqdm(urls):
    response = requests.get(url, headers={'name':'Anders Tørsløv','email':'fpb540@alumni.ku.dk'}) #requests and saves response
    html = response.text #saves html as text
    scrape.append(html) #adds html to the empty lyst
    log(response,logfile) #logs activity
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:03<00:00,  1.61it/s]

# %% [markdown]
# > **Ex. 6.1.6:** It is a good idea to build a scraper that can handle exceptions (for example a link that for some reason does not exist or connection problems). Build such an exception into your scraper from 6.1.5, so you do not loose the scraped data if it crashes halfway through.

# %%
import json
logfile = 'log2.csv'
scrape = []
for url in tqdm.tqdm(urls):
    try:
        response = requests.get(url, headers={'name':'Anders Tørsløv','email':'fpb540@alumni.ku.dk'})
    except Exception as e:
        print(url) #Print url
        print(e) #Print error
        with open('scrape', "w") as l: #Save the scrape list as a json file to retrieve at another time
            json.dump(scrape, l)
        continue #Continue to next iteration of the loop
        
    html = response.text
    scrape.append(html)
    log(response, logfile) # Log iterations
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:07<00:00,  1.43s/it]

# %% [markdown]
# # Part 2: Locating data through the network panel
#
# Sometimes you may be fortunate to find the request that the webpage sends to the server to retrieve the data for the webpage. In that case, we can just replicate the request to receive the data in a structured format (JSON). Then we do not need to struggle with the HTML-strings.
#
# To do this, we first need to find the request. For that purpose, the **network panel** in the Chrome Developer Tools is useful. The network panel monitors all the uploads and downloads to and from the webpage. You can read more about the network panel [here](https://developer.chrome.com/docs/devtools/network/).
#
# **Watch the video below (video 6.3) before working on the exercises.**

# %%
YouTubeVideo('isUxBDzfWMg', width=640, height=360)

# %% [markdown]
# > **Ex. 6.2.1:** Go to the job posting page at www.jobnet.dk again. Open the network panel and choose *Fetch/XHR* type ([Read more: XMLHttpRequest](https://en.wikipedia.org/wiki/XMLHttpRequest)). If you update the page, you will see all the XHR resources the page generates.
#
# > Go through all the XHRs and find the XHR that carries the information about the different job postings. What is the name of the XHR?
# >
# >*Note: There is no smart way to do this. You just need to go through all the XHRs and inspect the information they carry.*

# %% [markdown]
# ### Answer
# Your answer here

# %% [markdown]
# > **Ex. 6.2.2:** Use the request URL to download the JSON file consisting of the first 20 job postings. Return the request result in JSON format.

# %%
response = requests.get('https://job.jobnet.dk/CV/FindWork/Search', 
                        headers={'name':'Anders Tørsløv','email':'fpb540@alumni.ku.dk'})
result_json = response.json()

# %%
import pprint #Data pretty printer
pprint.pprint(response.json()) #Everything is aranged alphabetically and in appropriate levels
# Out:
# {'Expression': {'Abroad': False,
#                 'Count': 20,
#                 'EarliestPublicationDate': '0001-01-01T00:00:00',
#                 'ExternalJob': None,
#                 'Facets': {'Country': [],
#                            'EmploymentType': [],
#                            'HiringOrgName': [],
#                            'JobAnnouncementType': [],
#                            'Municipality': [],
#                            'OccupationAreas': [],
#                            'OccupationGroups': [],
#                            'Occupations': [],
#                            'PostalCode': [],
#                            'Region': [],
#                            'WorkHourPartTime': [],
#                            'WorkHours': [],
#                            'WorkPlaceNotStatic': []},
#                 'HotJob': False,
#                 'Id': [],
#                 'IsWorkInDenmarkJob': False,
#                 'LocatedIn': None,
#                 'Location': None,
#                 'LocationZip': None,
#                 'NearBy': None,
#                 'Offset': 0,
#                 'OnlyGeoPoints': False,
#                 'SearchInGeoDistance': 0,
#                 'SearchString': None,
#                 'ShowNearbyCriteria': True,
#                 'SortValue': None,
#                 'WorkHourMax': None,
#                 'WorkHourMin': None,
#                 'WorkPlaceNotStatic': None},
#  'Facets': {'Country': [{'Count': 22074, 'Id': 0, 'Value': 'Danmark'},
#                         {'Count': 74, 'Id': 0, 'Value': 'Grønland'},
#                         {'Count': 49, 'Id': 0, 'Value': 'Norge'},
#                         {'Count': 24, 'Id': 0, 'Value': 'Spanien'},
#                         {'Count': 13, 'Id': 0, 'Value': 'Portugal'},
#                         {'Count': 12, 'Id': 0, 'Value': 'Sverige'},
#                         {'Count': 12, 'Id': 0, 'Value': 'Malta'},
#                         {'Count': 11, 'Id': 0, 'Value': 'Irland'},
#                         {'Count': 11, 'Id': 0, 'Value': 'Grækenland'},
#                         {'Count': 9, 'Id': 0, 'Value': 'Tyskland'},
#                         {'Count': 9, 'Id': 0, 'Value': 'Polen'},
#                         {'Count': 8, 'Id': 0, 'Value': 'Letland'},
#                         {'Count': 6, 'Id': 0, 'Value': 'Tjekkiet'},
#                         {'Count': 5, 'Id': 0, 'Value': 'Nederlandene'},
#                         {'Count': 3, 'Id': 0, 'Value': 'Ungarn'},
#                         {'Count': 3, 'Id': 0, 'Value': 'Tyrkiet'},
#                         {'Count': 3, 'Id': 0, 'Value': 'Schweiz'},
#                         {'Count': 2, 'Id': 0, 'Value': 'Namibia'},
#                         {'Count': 2, 'Id': 0, 'Value': 'Finland'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Israel'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Filippinerne'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Storbritannien'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Slovenien'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Estland'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Bulgarien'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Belgien'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Egypten'},
#                         {'Count': 1, 'Id': 0, 'Value': 'Cypern'}],
#             'EmploymentType': [{'Count': 20132,
#                                 'Id': 0,
#                                 'Value': 'Fastansættelse'},
#                                {'Count': 2207,
#                                 'Id': 0,
#                                 'Value': 'Tidsbegrænset ansættelse'}],
#             'HiringOrgName': [],
#             'JobAnnouncementType': [{'Count': 21657,
#                                      'Id': 0,
#                                      'Value': 'Almindelige vilkår'},
#                                     {'Count': 379, 'Id': 0, 'Value': 'Hotjob'},
#                                     {'Count': 274,
#                                      'Id': 0,
#                                      'Value': 'Egnet til førtidspensionister'},
#                                     {'Count': 40,
#                                      'Id': 0,
#                                      'Value': 'Handicap ingen hindring'},
#                                     {'Count': 38,
#                                      'Id': 0,
#                                      'Value': 'Egnet til efterlønnere og '
#                                               'seniorer'},
#                                     {'Count': 27, 'Id': 0, 'Value': 'Fleksjob'},
#                                     {'Count': 11,
#                                      'Id': 0,
#                                      'Value': 'Rotationsjob'}],
#             'Municipality': [{'Count': 3316, 'Id': 0, 'Value': 'København'},
#                              {'Count': 1673, 'Id': 0, 'Value': 'Aarhus'},
#                              {'Count': 887, 'Id': 0, 'Value': 'Odense'},
#                              {'Count': 759, 'Id': 0, 'Value': 'Aalborg'},
#                              {'Count': 561, 'Id': 0, 'Value': 'Herning'},
#                              {'Count': 485, 'Id': 0, 'Value': 'Vejle'},
#                              {'Count': 465, 'Id': 0, 'Value': 'Esbjerg'},
#                              {'Count': 433, 'Id': 0, 'Value': 'Kolding'},
#                              {'Count': 427, 'Id': 0, 'Value': 'Roskilde'},
#                              {'Count': 379, 'Id': 0, 'Value': 'Frederiksberg'},
#                              {'Count': 358, 'Id': 0, 'Value': 'Viborg'},
#                              {'Count': 353, 'Id': 0, 'Value': 'Horsens'},
#                              {'Count': 336, 'Id': 0, 'Value': 'Gladsaxe'},
#                              {'Count': 317, 'Id': 0, 'Value': 'Silkeborg'},
#                              {'Count': 277, 'Id': 0, 'Value': 'Slagelse'},
#                              {'Count': 272, 'Id': 0, 'Value': 'Randers'},
#                              {'Count': 255, 'Id': 0, 'Value': 'Ballerup'},
#                              {'Count': 253, 'Id': 0, 'Value': 'Gentofte'},
#                              {'Count': 238, 'Id': 0, 'Value': 'Høje-Taastrup'},
#                              {'Count': 237, 'Id': 0, 'Value': 'Sønderborg'},
#                              {'Count': 235, 'Id': 0, 'Value': 'Holbæk'},
#                              {'Count': 234, 'Id': 0, 'Value': 'Skanderborg'},
#                              {'Count': 230, 'Id': 0, 'Value': 'Lyngby-Taarbæk'},
#                              {'Count': 219, 'Id': 0, 'Value': 'Hvidovre'},
#                              {'Count': 218, 'Id': 0, 'Value': 'Allerød'},
#                              {'Count': 214, 'Id': 0, 'Value': 'Frederikshavn'},
#                              {'Count': 213, 'Id': 0, 'Value': 'Næstved'},
#                              {'Count': 213, 'Id': 0, 'Value': 'Holstebro'},
#                              {'Count': 212, 'Id': 0, 'Value': 'Aabenraa'},
#                              {'Count': 211, 'Id': 0, 'Value': 'Glostrup'},
#                              {'Count': 203, 'Id': 0, 'Value': 'Køge'},
#                              {'Count': 195, 'Id': 0, 'Value': 'Hillerød'},
#                              {'Count': 193, 'Id': 0, 'Value': 'Tårnby'},
#                              {'Count': 187, 'Id': 0, 'Value': 'Rudersdal'},
#                              {'Count': 179, 'Id': 0, 'Value': 'Varde'},
#                              {'Count': 177,
#                               'Id': 0,
#                               'Value': 'Ringkøbing-Skjern'},
#                              {'Count': 175, 'Id': 0, 'Value': 'Haderslev'},
#                              {'Count': 174, 'Id': 0, 'Value': 'Svendborg'},
#                              {'Count': 171, 'Id': 0, 'Value': 'Fredericia'},
#                              {'Count': 168, 'Id': 0, 'Value': 'Ikast-Brande'},
#                              {'Count': 168, 'Id': 0, 'Value': 'Helsingør'},
#                              {'Count': 165, 'Id': 0, 'Value': 'Middelfart'},
#                              {'Count': 164, 'Id': 0, 'Value': 'Brøndby'},
#                              {'Count': 159, 'Id': 0, 'Value': 'Greve'},
#                              {'Count': 158, 'Id': 0, 'Value': 'Guldborgsund'},
#                              {'Count': 157, 'Id': 0, 'Value': 'Kalundborg'},
#                              {'Count': 143, 'Id': 0, 'Value': 'Lolland'},
#                              {'Count': 143, 'Id': 0, 'Value': 'Hedensted'},
#                              {'Count': 143, 'Id': 0, 'Value': 'Skive'},
#                              {'Count': 140, 'Id': 0, 'Value': 'Hjørring'},
#                              {'Count': 137, 'Id': 0, 'Value': 'Favrskov'},
#                              {'Count': 137, 'Id': 0, 'Value': 'Herlev'},
#                              {'Count': 136, 'Id': 0, 'Value': 'Rødovre'},
#                              {'Count': 128, 'Id': 0, 'Value': 'Frederikssund'},
#                              {'Count': 125, 'Id': 0, 'Value': 'Bornholm'},
#                              {'Count': 122, 'Id': 0, 'Value': 'Vejen'},
#                              {'Count': 121, 'Id': 0, 'Value': 'Mariagerfjord'},
#                              {'Count': 119, 'Id': 0, 'Value': 'Vordingborg'},
#                              {'Count': 119, 'Id': 0, 'Value': 'Furesø'},
#                              {'Count': 115, 'Id': 0, 'Value': 'Assens'},
#                              {'Count': 112, 'Id': 0, 'Value': 'Thisted'},
#                              {'Count': 111,
#                               'Id': 0,
#                               'Value': 'Faaborg-Midtfyn'},
#                              {'Count': 111, 'Id': 0, 'Value': 'Billund'},
#                              {'Count': 104, 'Id': 0, 'Value': 'Ringsted'},
#                              {'Count': 101, 'Id': 0, 'Value': 'Norddjurs'},
#                              {'Count': 99, 'Id': 0, 'Value': 'Fredensborg'},
#                              {'Count': 98, 'Id': 0, 'Value': 'Ishøj'},
#                              {'Count': 96, 'Id': 0, 'Value': 'Tønder'},
#                              {'Count': 94, 'Id': 0, 'Value': 'Albertslund'},
#                              {'Count': 93, 'Id': 0, 'Value': 'Sorø'},
#                              {'Count': 91, 'Id': 0, 'Value': 'Nyborg'},
#                              {'Count': 90, 'Id': 0, 'Value': 'Vesthimmerlands'},
#                              {'Count': 88, 'Id': 0, 'Value': 'Egedal'},
#                              {'Count': 84, 'Id': 0, 'Value': 'Jammerbugt'},
#                              {'Count': 77, 'Id': 0, 'Value': 'Gribskov'},
#                              {'Count': 75, 'Id': 0, 'Value': 'Odsherred'},
#                              {'Count': 75, 'Id': 0, 'Value': 'Brønderslev'},
#                              {'Count': 72, 'Id': 0, 'Value': 'Kerteminde'},
#                              {'Count': 69, 'Id': 0, 'Value': 'Hørsholm'},
#                              {'Count': 67, 'Id': 0, 'Value': 'Nordfyns'},
#                              {'Count': 67, 'Id': 0, 'Value': 'Rebild'},
#                              {'Count': 63, 'Id': 0, 'Value': 'Faxe'},
#                              {'Count': 55, 'Id': 0, 'Value': 'Halsnæs'},
#                              {'Count': 51, 'Id': 0, 'Value': 'Syddjurs'},
#                              {'Count': 46, 'Id': 0, 'Value': 'Odder'},
#                              {'Count': 43, 'Id': 0, 'Value': 'Lejre'},
#                              {'Count': 40, 'Id': 0, 'Value': 'Morsø'},
#                              {'Count': 39, 'Id': 0, 'Value': 'Stevns'},
#                              {'Count': 39, 'Id': 0, 'Value': 'Struer'},
#                              {'Count': 36, 'Id': 0, 'Value': 'Solrød'},
#                              {'Count': 36, 'Id': 0, 'Value': 'Vallensbæk'},
#                              {'Count': 33, 'Id': 0, 'Value': 'Dragør'},
#                              {'Count': 28, 'Id': 0, 'Value': 'Lemvig'},
#                              {'Count': 23, 'Id': 0, 'Value': 'Sermersooq'},
#                              {'Count': 19, 'Id': 0, 'Value': 'Langeland'},
#                              {'Count': 16, 'Id': 0, 'Value': 'Ærø'},
#                              {'Count': 15, 'Id': 0, 'Value': 'Avannaata'},
#                              {'Count': 8, 'Id': 0, 'Value': 'Fanø'},
#                              {'Count': 4, 'Id': 0, 'Value': 'Qeqqata'},
#                              {'Count': 3, 'Id': 0, 'Value': 'Kujalleq'},
#                              {'Count': 3, 'Id': 0, 'Value': 'Samsø'},
#                              {'Count': 2, 'Id': 0, 'Value': 'Qeqertalik'}],
#             'OccupationAreas': [{'Count': 3466,
#                                  'Id': 0,
#                                  'Value': 'Sundhed, omsorg og personlig pleje'},
#                                 {'Count': 2836,
#                                  'Id': 0,
#                                  'Value': 'Akademisk arbejde'},
#                                 {'Count': 2308,
#                                  'Id': 0,
#                                  'Value': 'Salg, indkøb og markedsføring'},
#                                 {'Count': 2012, 'Id': 0, 'Value': 'Ledelse'},
#                                 {'Count': 1990,
#                                  'Id': 0,
#                                  'Value': 'Pædagogisk, socialt og kirkeligt '
#                                           'arbejde'},
#                                 {'Count': 1387,
#                                  'Id': 0,
#                                  'Value': 'Hotel, restauration, køkken, '
#                                           'kantine '},
#                                 {'Count': 1213,
#                                  'Id': 0,
#                                  'Value': 'Bygge og anlæg'},
#                                 {'Count': 940,
#                                  'Id': 0,
#                                  'Value': 'Kontor, administration, regnskab og '
#                                           'finans'},
#                                 {'Count': 834, 'Id': 0, 'Value': 'Elever'},
#                                 {'Count': 824,
#                                  'Id': 0,
#                                  'Value': 'Jern, metal og auto'},
#                                 {'Count': 783,
#                                  'Id': 0,
#                                  'Value': 'Transport, post, lager- og '
#                                           'maskinførerarbejde'},
#                                 {'Count': 765,
#                                  'Id': 0,
#                                  'Value': 'Rengøring, ejendomsservice og '
#                                           'renovation'},
#                                 {'Count': 738,
#                                  'Id': 0,
#                                  'Value': 'It og teleteknik'},
#                                 {'Count': 676,
#                                  'Id': 0,
#                                  'Value': 'Undervisning og vejledning'},
#                                 {'Count': 487,
#                                  'Id': 0,
#                                  'Value': 'Vagt, sikkerhed og overvågning'},
#                                 {'Count': 460,
#                                  'Id': 0,
#                                  'Value': 'Industriel produktion'},
#                                 {'Count': 260,
#                                  'Id': 0,
#                                  'Value': 'Medie, kultur, turisme, idræt og '
#                                           'underholdning'},
#                                 {'Count': 141,
#                                  'Id': 0,
#                                  'Value': 'Landbrug, skovbrug, gartneri, '
#                                           'fiskeri og dyrepleje '},
#                                 {'Count': 127,
#                                  'Id': 0,
#                                  'Value': 'Nærings- og nydelsesmiddel'},
#                                 {'Count': 61,
#                                  'Id': 0,
#                                  'Value': 'Design, formgivning og grafisk '
#                                           'arbejde'},
#                                 {'Count': 19,
#                                  'Id': 0,
#                                  'Value': 'Træ, møbel, glas og keramik'},
#                                 {'Count': 12,
#                                  'Id': 0,
#                                  'Value': 'Tekstil og beklædning'}],
#             'OccupationGroups': [{'Count': 1721,
#                                   'Id': 0,
#                                   'Value': 'Pleje og omsorg'},
#                                  {'Count': 1605,
#                                   'Id': 0,
#                                   'Value': 'Pædagogisk arbejde'},
#                                  {'Count': 1160,
#                                   'Id': 0,
#                                   'Value': 'Butiksekspedition'},
#                                  {'Count': 968,
#                                   'Id': 0,
#                                   'Value': 'Sygepleje og jordemoderarbejde'},
#                                  {'Count': 934,
#                                   'Id': 0,
#                                   'Value': 'Salg og indkøb'},
#                                  {'Count': 908,
#                                   'Id': 0,
#                                   'Value': 'Køkken- og kantinearbejde'},
#                                  {'Count': 885,
#                                   'Id': 0,
#                                   'Value': 'Administrativt arbejde'},
#                                  {'Count': 597,
#                                   'Id': 0,
#                                   'Value': 'Rengøring mv.'},
#                                  {'Count': 573,
#                                   'Id': 0,
#                                   'Value': 'Salg, indkøb og markedsføring'},
#                                  {'Count': 538,
#                                   'Id': 0,
#                                   'Value': 'Øvrig ledelse'},
#                                  {'Count': 484,
#                                   'Id': 0,
#                                   'Value': 'Administration, strategi og '
#                                            'personale'},
#                                  {'Count': 427,
#                                   'Id': 0,
#                                   'Value': 'Servering mv.'},
#                                  {'Count': 424,
#                                   'Id': 0,
#                                   'Value': 'Kontor- og sekretærarbejde'},
#                                  {'Count': 399,
#                                   'Id': 0,
#                                   'Value': 'Lagerarbejde mv.'},
#                                  {'Count': 386,
#                                   'Id': 0,
#                                   'Value': 'Undervisning i grundskoler'},
#                                  {'Count': 349,
#                                   'Id': 0,
#                                   'Value': 'Ingeniørarbejde'},
#                                  {'Count': 346,
#                                   'Id': 0,
#                                   'Value': 'Systemudvikling, programmering og '
#                                            'design'},
#                                  {'Count': 343,
#                                   'Id': 0,
#                                   'Value': 'Tværgående arbejde, industriel '
#                                            'produktion'},
#                                  {'Count': 336,
#                                   'Id': 0,
#                                   'Value': 'Militært arbejde'},
#                                  {'Count': 294,
#                                   'Id': 0,
#                                   'Value': 'Elektrikerarbejde'},
#                                  {'Count': 286,
#                                   'Id': 0,
#                                   'Value': 'Vejtransport'},
#                                  {'Count': 282,
#                                   'Id': 0,
#                                   'Value': 'Behandling og genoptræning'},
#                                  {'Count': 269,
#                                   'Id': 0,
#                                   'Value': 'Økonomi og revision'},
#                                  {'Count': 268,
#                                   'Id': 0,
#                                   'Value': 'Socialrådgivning mv.'},
#                                  {'Count': 263,
#                                   'Id': 0,
#                                   'Value': 'Bogholderi- og regnskabsarbejde'},
#                                  {'Count': 258,
#                                   'Id': 0,
#                                   'Value': 'Mekanikerarbejde, transport'},
#                                  {'Count': 254,
#                                   'Id': 0,
#                                   'Value': 'Læge, tandlæge og dyrlæge'},
#                                  {'Count': 238,
#                                   'Id': 0,
#                                   'Value': 'Mekanikerarbejde, øvrigt'},
#                                  {'Count': 213,
#                                   'Id': 0,
#                                   'Value': 'Snedker-, tømrer- og glasarbejde'},
#                                  {'Count': 185,
#                                   'Id': 0,
#                                   'Value': 'Tværgående it-arbejde'},
#                                  {'Count': 173, 'Id': 0, 'Value': 'Marketing'},
#                                  {'Count': 168,
#                                   'Id': 0,
#                                   'Value': 'Forskning og '
#                                            'universitetsundervisning, '
#                                            'naturvidenskab og teknik '},
#                                  {'Count': 167,
#                                   'Id': 0,
#                                   'Value': 'Drift, support og netværk'},
#                                  {'Count': 166,
#                                   'Id': 0,
#                                   'Value': 'Juridisk arbejde'},
#                                  {'Count': 163,
#                                   'Id': 0,
#                                   'Value': 'Grov- og klejnsmedearbejde mv.'},
#                                  {'Count': 152,
#                                   'Id': 0,
#                                   'Value': 'Vvs og blik'},
#                                  {'Count': 150,
#                                   'Id': 0,
#                                   'Value': 'Ejendomsservice og måleraflæsning'},
#                                  {'Count': 147,
#                                   'Id': 0,
#                                   'Value': 'Drift og produktion'},
#                                  {'Count': 144,
#                                   'Id': 0,
#                                   'Value': 'Sundhedsområdet'},
#                                  {'Count': 140,
#                                   'Id': 0,
#                                   'Value': 'Administrativt sundhedsarbejde'},
#                                  {'Count': 132,
#                                   'Id': 0,
#                                   'Value': 'Bygningsarbejde mv.'},
#                                  {'Count': 130,
#                                   'Id': 0,
#                                   'Value': 'Organisation, udvikling og '
#                                            'rådgivning'},
#                                  {'Count': 128,
#                                   'Id': 0,
#                                   'Value': 'Psykologarbejde'},
#                                  {'Count': 116,
#                                   'Id': 0,
#                                   'Value': 'Bank og finans'},
#                                  {'Count': 115,
#                                   'Id': 0,
#                                   'Value': 'Hotel, køkken og restaurant'},
#                                  {'Count': 115, 'Id': 0, 'Value': 'Vejledning'},
#                                  {'Count': 115,
#                                   'Id': 0,
#                                   'Value': 'Medico- og laboratoriearbejde'},
#                                  {'Count': 111,
#                                   'Id': 0,
#                                   'Value': 'Institution'},
#                                  {'Count': 111,
#                                   'Id': 0,
#                                   'Value': 'Kontor, administration, regnskab '
#                                            'og finans'},
#                                  {'Count': 110,
#                                   'Id': 0,
#                                   'Value': 'Anlægsarbejde'},
#                                  {'Count': 108,
#                                   'Id': 0,
#                                   'Value': 'Hotel, restauration, køkken, '
#                                            'kantine '},
#                                  {'Count': 102,
#                                   'Id': 0,
#                                   'Value': 'Sundhed, omsorg og personlig '
#                                            'pleje'},
#                                  {'Count': 101,
#                                   'Id': 0,
#                                   'Value': 'Overvågning og kontrol'},
#                                  {'Count': 94,
#                                   'Id': 0,
#                                   'Value': 'Jern, metal og auto'},
#                                  {'Count': 88,
#                                   'Id': 0,
#                                   'Value': 'Arkitektarbejde, design og '
#                                            'planlægning '},
#                                  {'Count': 85,
#                                   'Id': 0,
#                                   'Value': 'Malerarbejde'},
#                                  {'Count': 84,
#                                   'Id': 0,
#                                   'Value': 'Murerarbejde'},
#                                  {'Count': 83,
#                                   'Id': 0,
#                                   'Value': 'Fritid og idræt'},
#                                  {'Count': 75,
#                                   'Id': 0,
#                                   'Value': 'Tandklinikarbejde'},
#                                  {'Count': 68,
#                                   'Id': 0,
#                                   'Value': 'Slagter- og fiskearbejde'},
#                                  {'Count': 67,
#                                   'Id': 0,
#                                   'Value': 'Maskinførerarbejde'},
#                                  {'Count': 66,
#                                   'Id': 0,
#                                   'Value': 'Børnepasning'},
#                                  {'Count': 64,
#                                   'Id': 0,
#                                   'Value': 'Forskning og '
#                                            'universitetsundervisning, '
#                                            'sundhedsvidenskab'},
#                                  {'Count': 64,
#                                   'Id': 0,
#                                   'Value': 'Øvrig undervisning'},
#                                  {'Count': 63,
#                                   'Id': 0,
#                                   'Value': 'Økonomi og finansiering'},
#                                  {'Count': 60,
#                                   'Id': 0,
#                                   'Value': 'Kran-og truckførerarbejde'},
#                                  {'Count': 59,
#                                   'Id': 0,
#                                   'Value': 'Undervisning og forskning'},
#                                  {'Count': 58,
#                                   'Id': 0,
#                                   'Value': 'Journalistik, skribent- og '
#                                            'mediearbejde'},
#                                  {'Count': 57,
#                                   'Id': 0,
#                                   'Value': 'Kommunikation og erhvervssprogligt '
#                                            'arbejde'},
#                                  {'Count': 54,
#                                   'Id': 0,
#                                   'Value': 'Maskinarbejde mv.'},
#                                  {'Count': 54,
#                                   'Id': 0,
#                                   'Value': 'Sang og musik'},
#                                  {'Count': 52,
#                                   'Id': 0,
#                                   'Value': 'Receptions- og kontorarbejde, '
#                                            'øvrigt'},
#                                  {'Count': 52,
#                                   'Id': 0,
#                                   'Value': 'Drift og produktion, landbrug'},
#                                  {'Count': 52,
#                                   'Id': 0,
#                                   'Value': 'Undervisning på fagskoler'},
#                                  {'Count': 50,
#                                   'Id': 0,
#                                   'Value': 'Politi- og redningsarbejde'},
#                                  {'Count': 49,
#                                   'Id': 0,
#                                   'Value': 'Teknisk sundhedsarbejde'},
#                                  {'Count': 49,
#                                   'Id': 0,
#                                   'Value': 'Øvrigt hotel-, køkken- og '
#                                            'husholdningsarbejde'},
#                                  {'Count': 49,
#                                   'Id': 0,
#                                   'Value': 'Nærings- og nydelsesmiddel'},
#                                  {'Count': 49,
#                                   'Id': 0,
#                                   'Value': 'Bager-, sukkervarer- og '
#                                            'kornarbejde'},
#                                  {'Count': 44,
#                                   'Id': 0,
#                                   'Value': 'Personlig pleje og skønhedspleje'},
#                                  {'Count': 42,
#                                   'Id': 0,
#                                   'Value': 'Forskning og '
#                                            'universitetsundervisning, '
#                                            'samfundsvidenskab '},
#                                  {'Count': 41,
#                                   'Id': 0,
#                                   'Value': 'Naturvidenskabeligt arbejde'},
#                                  {'Count': 40,
#                                   'Id': 0,
#                                   'Value': 'Test, kvalitet og sikkerhed'},
#                                  {'Count': 39,
#                                   'Id': 0,
#                                   'Value': 'Tværgående arbejde, bygge og '
#                                            'anlæg'},
#                                  {'Count': 38,
#                                   'Id': 0,
#                                   'Value': 'Sundhedsfremme og -forebyggelse'},
#                                  {'Count': 38,
#                                   'Id': 0,
#                                   'Value': 'Anlægsgartnerarbejde, produktion'},
#                                  {'Count': 37,
#                                   'Id': 0,
#                                   'Value': 'Metode- og planlægningsarbejde'},
#                                  {'Count': 35,
#                                   'Id': 0,
#                                   'Value': 'Specialundervisning'},
#                                  {'Count': 34,
#                                   'Id': 0,
#                                   'Value': 'Undervisning på '
#                                            'professionshøjskoler'},
#                                  {'Count': 34,
#                                   'Id': 0,
#                                   'Value': 'Bygge og anlæg'},
#                                  {'Count': 32,
#                                   'Id': 0,
#                                   'Value': 'Design og formgivning'},
#                                  {'Count': 32,
#                                   'Id': 0,
#                                   'Value': 'Jordbrug, miljø og grøn '
#                                            'forvaltning'},
#                                  {'Count': 31,
#                                   'Id': 0,
#                                   'Value': 'Autoklargøring mv.'},
#                                  {'Count': 30,
#                                   'Id': 0,
#                                   'Value': 'Elektro-, kabel- og tovarbejde'},
#                                  {'Count': 30,
#                                   'Id': 0,
#                                   'Value': 'Teologisk arbejde'},
#                                  {'Count': 29,
#                                   'Id': 0,
#                                   'Value': 'Øvrigt hospitalsarbejde '},
#                                  {'Count': 28,
#                                   'Id': 0,
#                                   'Value': 'Overfladebehandling'},
#                                  {'Count': 27,
#                                   'Id': 0,
#                                   'Value': 'Forskning og '
#                                            'universitetsundervisning, '
#                                            'humaniora '},
#                                  {'Count': 26,
#                                   'Id': 0,
#                                   'Value': 'Transport, post, lager- og '
#                                            'maskinførerarbejde'},
#                                  {'Count': 25,
#                                   'Id': 0,
#                                   'Value': 'Religiøst arbejde'},
#                                  {'Count': 24,
#                                   'Id': 0,
#                                   'Value': 'Undervisning på gymnasier og '
#                                            'højskoler'},
#                                  {'Count': 24,
#                                   'Id': 0,
#                                   'Value': 'Fagforeningsarbejde'},
#                                  {'Count': 24,
#                                   'Id': 0,
#                                   'Value': 'Ejendomshandel'},
#                                  {'Count': 22,
#                                   'Id': 0,
#                                   'Value': 'Rejser og turisme'},
#                                  {'Count': 21,
#                                   'Id': 0,
#                                   'Value': 'Svejsearbejde'},
#                                  {'Count': 21,
#                                   'Id': 0,
#                                   'Value': 'Gulv- og tagarbejde'},
#                                  {'Count': 21,
#                                   'Id': 0,
#                                   'Value': 'Have- og parkarbejde'},
#                                  {'Count': 19,
#                                   'Id': 0,
#                                   'Value': 'Transport, lager og logistik'},
#                                  {'Count': 19,
#                                   'Id': 0,
#                                   'Value': 'Tolkearbejde'},
#                                  {'Count': 19, 'Id': 0, 'Value': 'Forsikring'},
#                                  {'Count': 18,
#                                   'Id': 0,
#                                   'Value': 'Optræden, forlystelses- og '
#                                            'modelarbejde'},
#                                  {'Count': 18,
#                                   'Id': 0,
#                                   'Value': 'Pladesmedearbejde'},
#                                  {'Count': 18,
#                                   'Id': 0,
#                                   'Value': 'Bibliotekar- og arkivararbejde'},
#                                  {'Count': 18,
#                                   'Id': 0,
#                                   'Value': 'Montørarbejde'},
#                                  {'Count': 18,
#                                   'Id': 0,
#                                   'Value': 'Grafisk arbejde'},
#                                  {'Count': 17,
#                                   'Id': 0,
#                                   'Value': 'Dekorationsarbejde'},
#                                  {'Count': 17,
#                                   'Id': 0,
#                                   'Value': 'Træ- og møbelarbejde'},
#                                  {'Count': 17,
#                                   'Id': 0,
#                                   'Value': 'Medicoarbejde'},
#                                  {'Count': 16,
#                                   'Id': 0,
#                                   'Value': 'Fragt og shipping'},
#                                  {'Count': 15,
#                                   'Id': 0,
#                                   'Value': 'Landbrug, skovbrug, gartneri, '
#                                            'fiskeri og dyrepleje '},
#                                  {'Count': 14,
#                                   'Id': 0,
#                                   'Value': 'Tværgående arbejde, pædagogisk og '
#                                            'socialt arbejde'},
#                                  {'Count': 14,
#                                   'Id': 0,
#                                   'Value': 'Revisionsarbejde'},
#                                  {'Count': 14,
#                                   'Id': 0,
#                                   'Value': 'Autolakeringsarbejde'},
#                                  {'Count': 13,
#                                   'Id': 0,
#                                   'Value': 'Film-, tv- og teaterteknik'},
#                                  {'Count': 13,
#                                   'Id': 0,
#                                   'Value': 'It og teleteknik'},
#                                  {'Count': 13,
#                                   'Id': 0,
#                                   'Value': 'Kontorbetjentarbejde mv.'},
#                                  {'Count': 12,
#                                   'Id': 0,
#                                   'Value': 'Budarbejde mv.'},
#                                  {'Count': 12,
#                                   'Id': 0,
#                                   'Value': 'Isoleringsarbejde'},
#                                  {'Count': 12,
#                                   'Id': 0,
#                                   'Value': 'Begravelses- og kirkegårdsarbejde'},
#                                  {'Count': 11,
#                                   'Id': 0,
#                                   'Value': 'Renovation og gadefejning'},
#                                  {'Count': 11,
#                                   'Id': 0,
#                                   'Value': 'Rengøring, ejendomsservice og '
#                                            'renovation '},
#                                  {'Count': 11,
#                                   'Id': 0,
#                                   'Value': 'Plast-, fiber- og '
#                                            'skumgummiarbejde'},
#                                  {'Count': 10,
#                                   'Id': 0,
#                                   'Value': 'Kulturområdet'},
#                                  {'Count': 9,
#                                   'Id': 0,
#                                   'Value': 'Grafisk teknisk arbejde'},
#                                  {'Count': 9,
#                                   'Id': 0,
#                                   'Value': 'Gartneri, produktion'},
#                                  {'Count': 8,
#                                   'Id': 0,
#                                   'Value': 'Værktøjsmagerarbejde'},
#                                  {'Count': 8,
#                                   'Id': 0,
#                                   'Value': 'Kultur- og museumsarbejde'},
#                                  {'Count': 7,
#                                   'Id': 0,
#                                   'Value': 'Dyrepleje og opdræt'},
#                                  {'Count': 7, 'Id': 0, 'Value': 'Vask og rens'},
#                                  {'Count': 7, 'Id': 0, 'Value': 'Postarbejde'},
#                                  {'Count': 6,
#                                   'Id': 0,
#                                   'Value': 'Design, formgivning og grafisk '
#                                            'arbejde'},
#                                  {'Count': 6,
#                                   'Id': 0,
#                                   'Value': 'Tværgående arbejde, nærings- og '
#                                            'nydelsesmiddel'},
#                                  {'Count': 6,
#                                   'Id': 0,
#                                   'Value': 'Redaktionsarbejde'},
#                                  {'Count': 5,
#                                   'Id': 0,
#                                   'Value': 'Terapeutisk arbejde'},
#                                  {'Count': 5,
#                                   'Id': 0,
#                                   'Value': 'Lufttransport'},
#                                  {'Count': 5,
#                                   'Id': 0,
#                                   'Value': 'Dyrlægearbejde mv.'},
#                                  {'Count': 5,
#                                   'Id': 0,
#                                   'Value': 'Passagerservice'},
#                                  {'Count': 5,
#                                   'Id': 0,
#                                   'Value': 'Forskning og '
#                                            'universitetsundervisning, '
#                                            'teologi '},
#                                  {'Count': 5,
#                                   'Id': 0,
#                                   'Value': 'Beton-, tegl- og cementarbejde'},
#                                  {'Count': 4,
#                                   'Id': 0,
#                                   'Value': 'Tværgående arbejde, tekstil og '
#                                            'beklædning'},
#                                  {'Count': 4,
#                                   'Id': 0,
#                                   'Value': 'Maskinist-, dæks- og '
#                                            'kommunikationsarbejde til søs'},
#                                  {'Count': 4,
#                                   'Id': 0,
#                                   'Value': 'Rådgivning inden for landbrug, '
#                                            'skovbrug og gartneri'},
#                                  {'Count': 4,
#                                   'Id': 0,
#                                   'Value': 'Biblioteks- og museumsarbejde'},
#                                  {'Count': 4,
#                                   'Id': 0,
#                                   'Value': 'Vagt, sikkerhed og overvågning'},
#                                  {'Count': 4,
#                                   'Id': 0,
#                                   'Value': 'Foto- og kameraarbejde'},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Havneadministration'},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Mejeriarbejde'},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Skrædder-, sy- og '
#                                            'tilskærerarbejde '},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Skibsførerarbejde'},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Olie- og mineralarbejde'},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Sejl-, sadelmager- og '
#                                            'polstrerarbejde'},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Kemi- og medicinalarbejde'},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Kostforplejning på hospitaler og '
#                                            'andre institutioner'},
#                                  {'Count': 3,
#                                   'Id': 0,
#                                   'Value': 'Film, tv og teater - udøvende og '
#                                            'kreativt arbejde'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Jagt og fiskeri'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Drift og produktion, skovbrug'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Arbejde med kort, matrikel og '
#                                            'opmåling'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Øvrigt arbejde inden for tekstil '
#                                            'og beklædning mv.'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Bore- og udvindingsarbejde'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Model- og dekorationsarbejde'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Jernbanetransport'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Træ, møbel, glas og keramik'},
#                                  {'Count': 2,
#                                   'Id': 0,
#                                   'Value': 'Ædelmetalarbejde'},
#                                  {'Count': 1,
#                                   'Id': 0,
#                                   'Value': 'Dambrug og minkfarm'},
#                                  {'Count': 1,
#                                   'Id': 0,
#                                   'Value': 'Slibearbejde mv.'},
#                                  {'Count': 1,
#                                   'Id': 0,
#                                   'Value': 'Tapperiarbejde'},
#                                  {'Count': 1,
#                                   'Id': 0,
#                                   'Value': 'Instrumentbygning mv.'},
#                                  {'Count': 1,
#                                   'Id': 0,
#                                   'Value': 'Arbejde med sprog'},
#                                  {'Count': 1,
#                                   'Id': 0,
#                                   'Value': 'Medie, kultur, turisme, idræt og '
#                                            'underholdning'},
#                                  {'Count': 1,
#                                   'Id': 0,
#                                   'Value': 'Pædagogisk, socialt og teologisk '
#                                            'arbejde'}],
#             'Occupations': [{'Count': 980, 'Id': 0, 'Value': 'Pædagog'},
#                             {'Count': 875, 'Id': 0, 'Value': 'Sygeplejerske'},
#                             {'Count': 742,
#                              'Id': 0,
#                              'Value': 'Social- og sundhedsassistent'},
#                             {'Count': 693, 'Id': 0, 'Value': 'Butiksassistent'},
#                             {'Count': 530, 'Id': 0, 'Value': 'Handicaphjælper'},
#                             {'Count': 440,
# ...
#                           'Latitude': 55.3007,
#                           'Location': {'Latitude': 55.3007,
#                                        'Longitude': 11.5451},
#                           'Longitude': 11.5451,
#                           'Municipality': 'Næstved',
#                           'Occupation': 'Social- og sundhedsassistent',
#                           'OccupationArea': 'Sundhed, omsorg og personlig '
#                                             'pleje',
#                           'OccupationGroup': 'Pleje og omsorg',
#                           'OrganisationId': '57373',
#                           'PostalCode': '4250',
#                           'PostalCodeName': None,
#                           'PostingCreated': '2022-08-09T00:00:00',
#                           'Presentation': 'GENOPSLAGHar du ikke lyst til at '
#                                           'være en del af vores udekørende '
#                                           'team?Vi arbejder tværfagligt i et '
#                                           'tæt samarbejde mellem social- og '
#                                           'sundhedshjælpere',
#                           'Region': 'Øvrige Sjælland',
#                           'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5654777',
#                           'Title': 'SSA eller SSH til en fast stilling i '
#                                    'hjemmeplejen, Næstved By, Næstved Kommune',
#                           'Url': 'https://job.jobnet.dk/CV/FindWork/Details/5654777',
#                           'UseWorkPlaceAddressForJoblog': True,
#                           'UserLoggedIn': False,
#                           'Weight': 1.0,
#                           'WorkHours': 'Fuldtid',
#                           'WorkPlaceAbroad': False,
#                           'WorkPlaceAddress': 'Nattergalevej 1',
#                           'WorkPlaceCity': 'Fuglebjerg',
#                           'WorkPlaceNotStatic': False,
#                           'WorkPlaceOtherAddress': False,
#                           'WorkPlacePostalCode': '4250',
#                           'WorkplaceID': 93255},
#                          {'Abroad': False,
#                           'AnonymousEmployer': False,
#                           'AssignmentStartDate': '0001-01-01T00:00:00',
#                           'AutomatchType': 0,
#                           'Country': 'Danmark',
#                           'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5654776',
#                           'EmploymentType': '',
#                           'FormattedLastDateApplication': '4. oktober 2022',
#                           'HasLocationValues': True,
#                           'HiringOrgCVR': 42718130,
#                           'HiringOrgName': 'Restaurant Theo ApS',
#                           'ID': '5654776',
#                           'IsExternal': False,
#                           'IsHotjob': False,
#                           'JobAnnouncementType': '',
#                           'JobHeadline': 'Tjener til byens nye hippe sted',
#                           'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5654776',
#                           'JoblogWorkTime': {'DailyWorkTime': 'Dag',
#                                              'WorkHour': None},
#                           'LastDateApplication': '2022-10-04T00:00:00',
#                           'Latitude': 55.6793,
#                           'Location': {'Latitude': 55.6793,
#                                        'Longitude': 12.5744},
#                           'Longitude': 12.5744,
#                           'Municipality': 'København',
#                           'Occupation': 'Tjener',
#                           'OccupationArea': 'Hotel, restauration, køkken, '
#                                             'kantine ',
#                           'OccupationGroup': 'Servering mv.',
#                           'OrganisationId': '123819',
#                           'PostalCode': '1159',
#                           'PostalCodeName': None,
#                           'PostingCreated': '2022-08-09T00:00:00',
#                           'Presentation': 'Restaurant Theo søger en ny tjener '
#                                           'kollega til at joine en gruppe '
#                                           'livsglade kollegaer, som elsker at '
#                                           'gå på arbejde og have det sjovt '
#                                           'sammen hver dag!\n'
#                                           'Har du lyst til at arbejde med '
#                                           'mennesker',
#                           'Region': 'Hovedstaden og Bornholm',
#                           'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5654776',
#                           'Title': 'Tjener til byens nye hippe sted',
#                           'Url': 'https://job.jobnet.dk/CV/FindWork/Details/5654776',
#                           'UseWorkPlaceAddressForJoblog': True,
#                           'UserLoggedIn': False,
#                           'Weight': 1.0,
#                           'WorkHours': 'Fuldtid',
#                           'WorkPlaceAbroad': False,
#                           'WorkPlaceAddress': 'Skindergade 29',
#                           'WorkPlaceCity': 'København K',
#                           'WorkPlaceNotStatic': False,
#                           'WorkPlaceOtherAddress': False,
#                           'WorkPlacePostalCode': '1159',
#                           'WorkplaceID': 141646},
#                          {'Abroad': False,
#                           'AnonymousEmployer': False,
#                           'AssignmentStartDate': '0001-01-01T00:00:00',
#                           'AutomatchType': 0,
#                           'Country': 'Danmark',
#                           'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5654506',
#                           'EmploymentType': '',
#                           'FormattedLastDateApplication': '4. oktober 2022',
#                           'HasLocationValues': True,
#                           'HiringOrgCVR': 25244664,
#                           'HiringOrgName': "Bar'n v/Trine Jessen",
#                           'ID': '5654506',
#                           'IsExternal': False,
#                           'IsHotjob': False,
#                           'JobAnnouncementType': '',
#                           'JobHeadline': 'Deltids Bartender søges',
#                           'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5654506',
#                           'JoblogWorkTime': {'DailyWorkTime': 'Dag, aften, '
#                                                               'weekend',
#                                              'WorkHour': '(5 - 16 timer '
#                                                          'ugentligt)'},
#                           'LastDateApplication': '2022-10-04T00:00:00',
#                           'Latitude': 55.46,
#                           'Location': {'Latitude': 55.46, 'Longitude': 10.5611},
#                           'Longitude': 10.5611,
#                           'Municipality': 'Kerteminde',
#                           'Occupation': 'Bartender',
#                           'OccupationArea': 'Hotel, restauration, køkken, '
#                                             'kantine ',
#                           'OccupationGroup': 'Servering mv.',
#                           'OrganisationId': '107293',
#                           'PostalCode': '5330',
#                           'PostalCodeName': None,
#                           'PostingCreated': '2022-08-09T00:00:00',
#                           'Presentation': '\xa0Kunne du tænke dig et arbejde, '
#                                           'i en branche hvor humoren er i '
#                                           'centrum ?\n'
#                                           '\n'
#                                           '\n'
#                                           'Du har lige så solid rygrad, som '
#                                           'kunderne har dårlig humor.\n'
#                                           '\n'
#                                           '\n'
#                                           '\n'
#                                           '\n'
#                                           'Du elsker at multi',
#                           'Region': 'Syddanmark',
#                           'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5654506',
#                           'Title': 'Deltids Bartender søges',
#                           'Url': 'https://job.jobnet.dk/CV/FindWork/Details/5654506',
#                           'UseWorkPlaceAddressForJoblog': True,
#                           'UserLoggedIn': False,
#                           'Weight': 1.0,
#                           'WorkHours': 'Deltid',
#                           'WorkPlaceAbroad': False,
#                           'WorkPlaceAddress': 'Bycentret 208',
#                           'WorkPlaceCity': 'Munkebo',
#                           'WorkPlaceNotStatic': False,
#                           'WorkPlaceOtherAddress': False,
#                           'WorkPlacePostalCode': '5330',
#                           'WorkplaceID': 121027},
#                          {'Abroad': False,
#                           'AnonymousEmployer': False,
#                           'AssignmentStartDate': '0001-01-01T00:00:00',
#                           'AutomatchType': 0,
#                           'Country': 'Danmark',
#                           'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5654772',
#                           'EmploymentType': '',
#                           'FormattedLastDateApplication': '23. august 2022',
#                           'HasLocationValues': True,
#                           'HiringOrgCVR': 64942212,
#                           'HiringOrgName': 'Københavns Kommune',
#                           'ID': '5654772',
#                           'IsExternal': False,
#                           'IsHotjob': False,
#                           'JobAnnouncementType': '',
#                           'JobHeadline': 'Tre dygtige lærere til Damhusengens '
#                                          'Skole i Vanløse ',
#                           'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5654772',
#                           'JoblogWorkTime': {'DailyWorkTime': None,
#                                              'WorkHour': None},
#                           'LastDateApplication': '2022-08-23T00:00:00',
#                           'Latitude': 55.696,
#                           'Location': {'Latitude': 55.696,
#                                        'Longitude': 12.5253},
#                           'Longitude': 12.5253,
#                           'Municipality': 'København',
#                           'Occupation': 'Folkeskolelærer',
#                           'OccupationArea': 'Undervisning og vejledning',
#                           'OccupationGroup': 'Undervisning i grundskoler',
#                           'OrganisationId': '36699',
#                           'PostalCode': '2400',
#                           'PostalCodeName': None,
#                           'PostingCreated': '2022-08-09T00:00:00',
#                           'Presentation': 'Er du fagligt stærk, og kan du '
#                                           'omsætte klogskab til virkelighed, '
#                                           'smile og kommunikere og samtidig '
#                                           'balancere i et til tider '
#                                           'kompliceret felt med blikket '
#                                           'fastholdt på målet: at opgaven '
#                                           'handler o',
#                           'Region': 'Hovedstaden og Bornholm',
#                           'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5654772',
#                           'Title': 'Tre dygtige lærere til Damhusengens Skole '
#                                    'i Vanløse ',
#                           'Url': 'https://job.jobnet.dk/CV/FindWork/Details/5654772',
#                           'UseWorkPlaceAddressForJoblog': True,
#                           'UserLoggedIn': False,
#                           'Weight': 1.0,
#                           'WorkHours': 'Fuldtid',
#                           'WorkPlaceAbroad': False,
#                           'WorkPlaceAddress': 'Borups Allé 177',
#                           'WorkPlaceCity': 'København NV',
#                           'WorkPlaceNotStatic': False,
#                           'WorkPlaceOtherAddress': False,
#                           'WorkPlacePostalCode': '2400',
#                           'WorkplaceID': 76595},
#                          {'Abroad': False,
#                           'AnonymousEmployer': False,
#                           'AssignmentStartDate': '0001-01-01T00:00:00',
#                           'AutomatchType': 0,
#                           'Country': 'Danmark',
#                           'DetailsUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5654771',
#                           'EmploymentType': '',
#                           'FormattedLastDateApplication': '4. oktober 2022',
#                           'HasLocationValues': True,
#                           'HiringOrgCVR': 26236231,
#                           'HiringOrgName': 'Carl Hansen & Søn',
#                           'ID': '5654771',
#                           'IsExternal': False,
#                           'IsHotjob': False,
#                           'JobAnnouncementType': '',
#                           'JobHeadline': 'LAGERMEDARBEJDERE',
#                           'JobLogUrl': 'https://job.jobnet.dk/CV/FindWork/Details/5654771',
#                           'JoblogWorkTime': {'DailyWorkTime': None,
#                                              'WorkHour': None},
#                           'LastDateApplication': '2022-10-04T00:00:00',
#                           'Latitude': 55.3928,
#                           'Location': {'Latitude': 55.3928,
#                                        'Longitude': 9.9378},
#                           'Longitude': 9.9378,
#                           'Municipality': 'Middelfart',
#                           'Occupation': 'Lager- og logistikmedarbejder',
#                           'OccupationArea': 'Transport, post, lager- og '
#                                             'maskinførerarbejde',
#                           'OccupationGroup': 'Lagerarbejde mv.',
#                           'OrganisationId': '27874',
#                           'PostalCode': '5591',
#                           'PostalCodeName': None,
#                           'PostingCreated': '2022-08-09T00:00:00',
#                           'Presentation': 'Carl Hansen & Søn A/S oplever en '
#                                           'øget global efterspørgsel efter '
#                                           'virksomhedens kvalitetsmøbler samt '
#                                           'accessories. Med udgangspunkt i et '
#                                           'stærkt og anerkendt produktprogram, '
#                                           'som i dag markedsføres bre',
#                           'Region': 'Syddanmark',
#                           'ShareUrl': 'https://job.jobnet.dk/CV/FindWork/DetailsSocialmedia/5654771',
#                           'Title': 'LAGERMEDARBEJDERE',
#                           'Url': 'https://job.jobnet.dk/CV/FindWork/Details/5654771',
#                           'UseWorkPlaceAddressForJoblog': True,
#                           'UserLoggedIn': False,
#                           'Weight': 1.0,
#                           'WorkHours': 'Fuldtid',
#                           'WorkPlaceAbroad': False,
#                           'WorkPlaceAddress': 'Hylkedamvej 77',
#                           'WorkPlaceCity': 'Gelsted',
#                           'WorkPlaceNotStatic': False,
#                           'WorkPlaceOtherAddress': False,
#                           'WorkPlacePostalCode': '5591',
#                           'WorkplaceID': 121019}],
#  'TotalResultCount': 22339}

# %% [markdown]
# > **Ex. 6.2.3:** The JSON file consists of three different key-value pairs. We are only interested in the pair that contains the job postings. Find the right key-value pair and convert the JSON data to a Pandas dataframe.

# %%
import pandas as pd

df_jobs = pd.DataFrame(result_json['JobPositionPostings'])

df_jobs.head(5)
# Out:
#    AutomatchType  Abroad  Weight  \
# 0              0   False     1.0
# 1              0   False     1.0
# 2              0   False     1.0
# 3              0   False     1.0
# 4              0   False     1.0
#
#                                                Title  \
# 0  MOSS COPENHAGEN SØGER SALES ASSISTANT FULDTID,...
# 1  Dygtig køkkenassistent til Dagtilbuddene i Tom...
# 2  Medarbejder til produktionsvirksomhed i Juelsm...
# 3  Hundslund Skole søger pædagog med specialpædag...
# 4  Konsulent med kulturforandring på hjernen og k...
#
#                                          JobHeadline  \
# 0  MOSS COPENHAGEN SØGER SALES ASSISTANT FULDTID,...
# 1  Dygtig køkkenassistent til Dagtilbuddene i Tom...
# 2  Medarbejder til produktionsvirksomhed i Juelsm...
# 3  Hundslund Skole søger pædagog med specialpædag...
# 4  Konsulent med kulturforandring på hjernen og k...
#
#                                         Presentation  \
# 0  Vi søger en Sales Assistant til vores butik i ...
# 1  Får du god energi af at arbejde i et hus, der ...
# 2  Har du hænderne skruet rigtigt på, og kan du l...
# 3  Stillingen er på 25 timer pr. uge med tiltræde...
# 4  Vil du være med til at gøre klima og verdensmå...
#
#                       HiringOrgName        WorkPlaceAddress  \
# 0                      MOSS CPH A/S  Arne Jacobsens Allé 12
# 1  Assens Kommune - Overmarksgården           Rådhus Allé 5
# 2                        Moment A/S
# 3                   Hundslund Skole           Landevejen 30
# 4                  Gentofte Kommune      Bernstorffsvej 161
#
#   WorkPlacePostalCode   WorkPlaceCity  ...  HiringOrgCVR  UserLoggedIn  \
# 0                2300     København S  ...      37424366         False
# 1                5610          Assens  ...      29189692         False
# 2                7150          Barrit  ...      25328949         False
# 3                8350       Hundslund  ...      32264328         False
# 4                2920  Charlottenlund  ...      19438414         False
#
#    AnonymousEmployer                                           ShareUrl  \
# 0              False  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 1              False  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 2              False  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 3              False  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
# 4              False  https://job.jobnet.dk/CV/FindWork/DetailsSocia...
#
#                                           DetailsUrl  \
# 0  https://job.jobnet.dk/CV/FindWork/Details/5654786
# 1  https://job.jobnet.dk/CV/FindWork/Details/5654787
# 2  https://job.jobnet.dk/CV/FindWork/Details/5654521
# 3  https://job.jobnet.dk/CV/FindWork/Details/5654520
# 4  https://job.jobnet.dk/CV/FindWork/Details/5654785
#
#                                            JobLogUrl HasLocationValues  \
# 0  https://job.jobnet.dk/CV/FindWork/Details/5654786              True
# 1  https://job.jobnet.dk/CV/FindWork/Details/5654787              True
# 2  https://job.jobnet.dk/CV/FindWork/Details/5654521              True
# 3  https://job.jobnet.dk/CV/FindWork/Details/5654520              True
# 4  https://job.jobnet.dk/CV/FindWork/Details/5654785              True
#
#         ID  Latitude  Longitude
# 0  5654786   55.6310    12.5759
# 1  5654787   55.2666     9.8928
# 2  5654521   55.6870     9.8978
# 3  5654520   55.9147    10.0533
# 4  5654785   55.7494    12.5564
#
# [5 rows x 46 columns]

# %% [markdown]
# > **Ex. 6.2.4:** At this point, we have information about the first 20 job postings. Now we want the job postings of the first 5 pages, i.e. the first 100 job postings.
#
# > Use the same procedure as in **Ex. 6.1.3-4** to download the first 100 postings and save them in a dataframe.
# >
# > *Note: Remember to limit the rate of your calls, log your activity, and think about how to handle exceptions.*
#
# > *Hint: Recall the paging parameter from **Ex. 6.1.2**. You can use the same paging parameter in the new request URL to loop through the 5 pages.*

# %%
import json
#req_urls = [f'https://job.jobnet.dk/CV/FindWork?Offset={n*20}&SortValue=BestMatch' for n in range(5)]
req_urls = [f'https://job.jobnet.dk/CV/FindWork/Search?Offset={n*20}' for n in range(5)]
#print(req_urls)
logfile = 'log.csv'
df_job100 = pd.DataFrame()
for url in tqdm.tqdm(req_urls):
    try:
        response = requests.get(url, headers={'name':'Anders Tørsløv','email':'fpb540@alumni.ku.dk'})
    except Exception as e:
        print(url) #Print url
        print(e) #Print error
        df_job100.to_csv('df_job100.csv')
        continue #Continue to next iteration of the loop
    
    if response.ok: #Check if the response carries any data
        result_json = response.json() #If the response carries data, then convert it to json format
    
    else: #If the response does not carry any data, then print the status_code and continue to next iteration of the loop
        print(response.status_code)
        continue
    
    result_df = pd.DataFrame(result_json['JobPositionPostings']) #Convert this iteration's json file to a dataframe
    df_job100 = pd.concat([df_job100, result_df], axis=0, ignore_index=True) #Append to the rest of the data
    log(response, logfile)
    time.sleep(0.5) #Sleep for 0.5 seconds
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████| 5/5 [00:27<00:00,  5.49s/it]

# %% [markdown]
# > **Ex. 6.2.5 (optional):** What are the top 5 occupation areas with most job postings out of the 100 postings? How many job postings do the top 5 occupation areas have each?

# %%
#df_job100.head(5)
#print(df_job100.columns)

df_job100.groupby(df_job100['OccupationArea'])['ID'].count().sort_values(ascending=False)[0:5]
# Out:
# OccupationArea
# Sundhed, omsorg og personlig pleje          18
# Pædagogisk, socialt og kirkeligt arbejde    16
# Akademisk arbejde                           12
# Hotel, restauration, køkken, kantine         9
# Salg, indkøb og markedsføring                7
# Name: ID, dtype: int64
